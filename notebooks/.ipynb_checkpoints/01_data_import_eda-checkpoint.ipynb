# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('raw_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 53 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   Attrition                          1470 non-null   int64
#  2   DailyRate                          1470 non-null   int64
#  3   DistanceFromHome                   1470 non-null   int64
#  4   Education                          1470 non-null   int64
#  5   EmployeeCount                      1470 non-null   int64
#  6   EmployeeNumber                     1470 non-null   int64
#  7   EnvironmentSatisfaction            1470 non-null   int64
#  8   Gender                             1470 non-null   int64
#  9   HourlyRate                         1470 non-null   int64
#  10  JobInvolvement                     1470 non-null   int64
#  11  JobLevel                           1470 non-null   int64
#  12  JobSatisfaction                    1470 non-null   int64
#  13  MonthlyIncome                      1470 non-null   int64
#  14  MonthlyRate                        1470 non-null   int64
#  15  NumCompaniesWorked                 1470 non-null   int64
#  16  OverTime                           1470 non-null   int64
#  17  PercentSalaryHike                  1470 non-null   int64
#  18  PerformanceRating                  1470 non-null   int64
#  19  RelationshipSatisfaction           1470 non-null   int64
#  20  StandardHours                      1470 non-null   int64
#  21  StockOptionLevel                   1470 non-null   int64
#  22  TotalWorkingYears                  1470 non-null   int64
#  23  TrainingTimesLastYear              1470 non-null   int64
#  24  WorkLifeBalance                    1470 non-null   int64
#  25  YearsAtCompany                     1470 non-null   int64
#  26  YearsInCurrentRole                 1470 non-null   int64
#  27  YearsSinceLastPromotion            1470 non-null   int64
#  28  YearsWithCurrManager               1470 non-null   int64
#  29  JobRole_Healthcare Representative  1470 non-null   bool
#  30  JobRole_Human Resources            1470 non-null   bool
#  31  JobRole_Laboratory Technician      1470 non-null   bool
#  32  JobRole_Manager                    1470 non-null   bool
#  33  JobRole_Manufacturing Director     1470 non-null   bool
#  34  JobRole_Research Director          1470 non-null   bool
#  35  JobRole_Research Scientist         1470 non-null   bool
#  36  JobRole_Sales Executive            1470 non-null   bool
#  37  JobRole_Sales Representative       1470 non-null   bool
#  38  MaritalStatus_Divorced             1470 non-null   bool
#  39  MaritalStatus_Married              1470 non-null   bool
#  40  MaritalStatus_Single               1470 non-null   bool
#  41  BusinessTravel_Non-Travel          1470 non-null   bool
#  42  BusinessTravel_Travel_Frequently   1470 non-null   bool
#  43  BusinessTravel_Travel_Rarely       1470 non-null   bool
#  44  Department_Human Resources         1470 non-null   bool
#  45  Department_Research & Development  1470 non-null   bool
#  46  Department_Sales                   1470 non-null   bool
#  47  EducationField_Human Resources     1470 non-null   bool
#  48  EducationField_Life Sciences       1470 non-null   bool
#  49  EducationField_Marketing           1470 non-null   bool
#  50  EducationField_Medical             1470 non-null   bool
#  51  EducationField_Other               1470 non-null   bool
#  52  EducationField_Technical Degree    1470 non-null   bool
# dtypes: bool(24), int64(29)
# memory usage: 367.6 KB

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df['BusinessTravel'].value_counts()
# Out:
# BusinessTravel
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      882
# Female    588
# Name: count, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     673
# Single      470
# Divorced    327
# Name: count, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Over18
# Y    1470
# Name: count, dtype: int64

# %%
df['OverTime'].value_counts()
# Out:
# OverTime
# No     1054
# Yes     416
# Name: count, dtype: int64

# %%
df.drop('Over18' , inplace = True , axis = 1)

# %%
df['OverTime'] = df['OverTime'].map({'No' : 1 , 'Yes' : 0})

# %%
df['Gender'] = df['Gender'].map({'Male' : 1 , 'Female' : 0})

# %%
df['Attrition'] = df['Attrition'].map({'No' : 1 , 'Yes' : 0})

# %%
cols = ['JobRole' , 'MaritalStatus' , 'BusinessTravel' , 'Department' , 'EducationField']

# %%
df = pd.get_dummies(df , columns = cols , drop_first = False)

# %%
df['EducationField_Other'].value_counts()
# Out:
# EducationField_Other
# False    1388
# True       82
# Name: count, dtype: int64

# %%
cols2 = [
    'JobRole_Healthcare Representative',
    'JobRole_Human Resources',
    'JobRole_Laboratory Technician',
    'JobRole_Manager',
    'JobRole_Manufacturing Director',
    'JobRole_Research Director',
    'JobRole_Research Scientist',
    'JobRole_Sales Executive',
    'JobRole_Sales Representative',
    'MaritalStatus_Divorced',
    'MaritalStatus_Married',
    'MaritalStatus_Single',
    'BusinessTravel_Non-Travel',
    'BusinessTravel_Travel_Frequently',
    'BusinessTravel_Travel_Rarely',
    'Department_Human Resources',
    'Department_Research & Development',
    'Department_Sales',
    'EducationField_Human Resources',
    'EducationField_Life Sciences',
    'EducationField_Marketing',
    'EducationField_Medical',
    'EducationField_Other',
    'EducationField_Technical Degree'
]

# %%
df[cols2] = df[cols2].astype(int)

# %%
df.describe()
df.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Attrition'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'Education'}>,
#         <Axes: title={'center': 'EmployeeCount'}>,
#         <Axes: title={'center': 'EmployeeNumber'}>],
#        [<Axes: title={'center': 'EnvironmentSatisfaction'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'HourlyRate'}>,
#         <Axes: title={'center': 'JobInvolvement'}>,
#         <Axes: title={'center': 'JobLevel'}>,
#         <Axes: title={'center': 'JobSatisfaction'}>,
#         <Axes: title={'center': 'MonthlyIncome'}>],
#        [<Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>,
#         <Axes: title={'center': 'OverTime'}>,
#         <Axes: title={'center': 'PercentSalaryHike'}>,
#         <Axes: title={'center': 'PerformanceRating'}>,
#         <Axes: title={'center': 'RelationshipSatisfaction'}>,
#         <Axes: title={'center': 'StandardHours'}>],
#        [<Axes: title={'center': 'StockOptionLevel'}>,
#         <Axes: title={'center': 'TotalWorkingYears'}>,
#         <Axes: title={'center': 'TrainingTimesLastYear'}>,
#         <Axes: title={'center': 'WorkLifeBalance'}>,
#         <Axes: title={'center': 'YearsAtCompany'}>,
#         <Axes: title={'center': 'YearsInCurrentRole'}>,
#         <Axes: title={'center': 'YearsSinceLastPromotion'}>],
#        [<Axes: title={'center': 'YearsWithCurrManager'}>,
#         <Axes: title={'center': 'JobRole_Healthcare Representative'}>,
#         <Axes: title={'center': 'JobRole_Human Resources'}>,
#         <Axes: title={'center': 'JobRole_Laboratory Technician'}>,
#         <Axes: title={'center': 'JobRole_Manager'}>,
#         <Axes: title={'center': 'JobRole_Manufacturing Director'}>,
#         <Axes: title={'center': 'JobRole_Research Director'}>],
#        [<Axes: title={'center': 'JobRole_Research Scientist'}>,
#         <Axes: title={'center': 'JobRole_Sales Executive'}>,
#         <Axes: title={'center': 'JobRole_Sales Representative'}>,
#         <Axes: title={'center': 'MaritalStatus_Divorced'}>,
#         <Axes: title={'center': 'MaritalStatus_Married'}>,
#         <Axes: title={'center': 'MaritalStatus_Single'}>,
#         <Axes: title={'center': 'BusinessTravel_Non-Travel'}>],
#        [<Axes: title={'center': 'BusinessTravel_Travel_Frequently'}>,
#         <Axes: title={'center': 'BusinessTravel_Travel_Rarely'}>,
#         <Axes: title={'center': 'Department_Human Resources'}>,
#         <Axes: title={'center': 'Department_Research & Development'}>,
#         <Axes: title={'center': 'Department_Sales'}>,
#         <Axes: title={'center': 'EducationField_Human Resources'}>,
#         <Axes: title={'center': 'EducationField_Life Sciences'}>],
#        [<Axes: title={'center': 'EducationField_Marketing'}>,
#         <Axes: title={'center': 'EducationField_Medical'}>,
#         <Axes: title={'center': 'EducationField_Other'}>,
#         <Axes: title={'center': 'EducationField_Technical Degree'}>,
#         <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
df.to_csv('cleaned_data.csv' , index = False)
